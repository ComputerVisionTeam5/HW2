# %%
from functions import *

# %%
image = cv.imread('imgs/test2.jpg')
image2 = cv.imread('imgs/test3.jpg')
image3 = cv.imread('imgs/test4.jpg')

# %% [markdown]
# ## Region Growing Algortihm

# %%
naive_region_growing(image,0, tiling_size=20, factor=2, maxpool_factor=4)
# Out:
# c:\Users\13042\anaconda3\envs\my_env\lib\site-packages\numpy\core\_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\13042\anaconda3\envs\my_env\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\13042\anaconda3\envs\my_env\lib\site-packages\numpy\core\_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 33596

# %%
region_growing_2(image,0, resize_factor=4, maxpool_factor=4, T_threshold=2.4, merge_threshold=20,cycles_pre=3, cycles_pos=8, init="upper")
# Out:
# 126

# %%
region_growing_2(image2,0, resize_factor=2, maxpool_factor=2, T_threshold=2.4, merge_threshold=20, cycles_pre=3, cycles_pos=12, init="upper")
# Out:
# 179

# %%
region_growing_2(image3,0, resize_factor=2, maxpool_factor=4, T_threshold=1.6, merge_threshold=3.4, cycles_pre=0, cycles_pos=4, init="upper")
# Out:
# 617

# %% [markdown]
# ## Clustering Algorithms

# %% [markdown]
# ### K-means

# %%
images = [image, image2, image3]
for image in images:
    _ = kmeans_segmentation(image, k=7)

# %% [markdown]
# ### Fuzzy -c means
